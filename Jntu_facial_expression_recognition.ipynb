# %% [markdown]
# <a href="https://colab.research.google.com/github/D-S-Sahithi/chatbotsahi/blob/main/Jntu_facial_expression_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 10.8 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=f7f1d296778b3793fa0265cce2c51bc36b57619987554fc883a79e2460d06612
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 24-03-15 09:49:26 - Directory /root/.deepface created
# 24-03-15 09:49:26 - Directory /root/.deepface/weights created

# %%
img_path="/content/Pasted image.png"

# %%
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open("/content/Pasted image.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
result=DeepFace.analyze(img_path,actions=["emotion"])
# Out:
# 24-03-15 09:58:03 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 20.7MB/s]

# %%
from deepface import DeepFace

# %%
for face in result:
  emotion=face["dominant_emotion"]
  print("Dominant emotion:",emotion)
# Out:
# Dominant emotion: happy

# %%
for face in result:
  print("Face Region:",face["region"])
# Out:
# Face Region: {'x': 176, 'y': 34, 'w': 87, 'h': 87, 'left_eye': (29, 32), 'right_eye': (58, 39)}

# %%
img_2="/content/Pasted image 1.png"

# %%
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open("/content/Pasted image 1.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
result=DeepFace.analyze(img_2,actions=["emotion"])

# %%
for face in result:
  em=face["dominant_emotion"]
  print("Face emotion:",em)
# Out:
# Face emotion: sad

# %%
for face in result:
  print("face region",face["region"])
# Out:
# face region {'x': 52, 'y': 23, 'w': 128, 'h': 128, 'left_eye': (46, 52), 'right_eye': (85, 49)}
